# %%
import pandas as pd

# %%
temp = [-20, -10, 10 , 20]
print(temp)
# Out:
# [-20, -10, 10, 20]

# %%
temp = pd.Series(temp, index=['1월', '2월', '3월', '4월'])
temp, type(temp)
# Out:
# (1월   -20
#  2월   -10
#  3월    10
#  4월    20
#  dtype: int64,
#  pandas.core.series.Series)

# %%
temp['1월']
# Out:
# np.int64(-20)
