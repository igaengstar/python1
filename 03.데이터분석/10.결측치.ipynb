# %%
import pandas as pd

# %%
df = pd.read_csv['data/score.csv', index_col = '지원번호']
df                                                                                                                                                                                                                                                                               ]]]]]]]]]
# Out:
#   Cell In[5], line 1
#     df = pd.read_csv['data/score.csv', index_col = '지원번호']
#                                                  ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
df = df.copy()
df['학교'] =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = df.copy()
#       2 df['학교'] = np.where(df['학교'] == '북산고', '상산고', df['학교'])
#       3 df['학교'] = np.where(df['학교'] == '능남고', '상산고', df['학교'])
#
# NameError: name 'df' is not defined
